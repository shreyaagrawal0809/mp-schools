# %%
#import libraries
import pandas as pd
import seaborn as sns
#read csv file
dataframe = pd.read_csv(r'C:\Users\Admin\Desktop\kaggle-master\kaggle-master\train.csv')

# %%
dataframe
# Out:
#      survived  pclass                                               name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# 6           0       1                            McCarthy, Mr. Timothy J
# 7           0       3                     Palsson, Master. Gosta Leonard
# 8           1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9           1       2                Nasser, Mrs. Nicholas (Adele Achem)
# 10          1       3                    Sandstrom, Miss. Marguerite Rut
# 11          1       1                           Bonnell, Miss. Elizabeth
# ...

# %%
#describe 
dataframe.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
#print name of columns
dataframe.columns
# Out:
# Index(['survived', 'pclass', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked'],
#       dtype='object')

# %%
#type of dataframe
type(dataframe)
# Out:
# pandas.core.frame.DataFrame

# %%
#to find number of rows and columns
dataframe.shape
# Out:
# (891, 11)

# %%
#print the index
dataframe.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
# to print that the column of a dataframe is series type
type(dataframe['sex'])
# Out:
# pandas.core.series.Series

# %%
sns.countplot(x = 'sex',hue = 'survived', data = dataframe)

# %%
#this dataframe contains column which has no null entries
df = dataframe.loc[:,dataframe.notnull().all()]

# %%
h_index = df.set_index(['sex','survived'],inplace = False)
h_index.sort_index()
# Out:
#                  pclass                                               name  \
# sex    survived
# female 0              3               Vestrom, Miss. Hulda Amanda Adolfina
#        0              3  Vander Planke, Mrs. Julius (Emelia Maria Vande...
#        0              3                      Palsson, Miss. Torborg Danira
#        0              3                 Vander Planke, Miss. Augusta Maria
#        0              3     Ahlin, Mrs. Johan (Johanna Persdotter Larsson)
#        0              2  Turpin, Mrs. William John Robert (Dorothy Ann ...
#        0              3      Arnold-Franchi, Mrs. Josef (Josefine Franchi)
#        0              3                         Goodwin, Miss. Lillian Amy
#        0              3                            Petranec, Miss. Matilda
#        0              3                               Zabour, Miss. Hileni
#        0              3                            Jussila, Miss. Katriina
# ...

# %%
dataframe
# Out:
#      survived  pclass                                               name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# 6           0       1                            McCarthy, Mr. Timothy J
# 7           0       3                     Palsson, Master. Gosta Leonard
# 8           1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9           1       2                Nasser, Mrs. Nicholas (Adele Achem)
# 10          1       3                    Sandstrom, Miss. Marguerite Rut
# 11          1       1                           Bonnell, Miss. Elizabeth
# ...

# %%
#counting the number of females 
count_fe = df.loc[df['sex'] == 'female' ].count()
count_fe
# Out:
# survived    314
# pclass      314
# name        314
# sex         314
# sibsp       314
# parch       314
# ticket      314
# fare        314
# dtype: int64

# %%
#number of males
count_ma = df.loc[df['sex'] == 'male'].count()
count_ma
# Out:
# survived    577
# pclass      577
# name        577
# sex         577
# sibsp       577
# parch       577
# ticket      577
# fare        577
# dtype: int64

# %%
#difference between number of males and females differ
count_differ = count_ma - count_fe
count_differ
# Out:
# survived    263
# pclass      263
# name        263
# sex         263
# sibsp       263
# parch       263
# ticket      263
# fare        263
# dtype: int64

# %%
#using group by
df.groupby('sex').count()
# Out:
#         survived  pclass  name  sibsp  parch  ticket  fare
# sex
# female       314     314   314    314    314     314   314
# male         577     577   577    577    577     577   577

# %%
df.groupby('sex')['survived'].sum()
# Out:
# sex
# female    233
# male      109
# Name: survived, dtype: int64

# %%
#printing the fare column of dataset
df['fare']
# Out:
# 0        7.2500
# 1       71.2833
# 2        7.9250
# 3       53.1000
# 4        8.0500
# 5        8.4583
# 6       51.8625
# 7       21.0750
# 8       11.1333
# 9       30.0708
# 10      16.7000
# 11      26.5500
# 12       8.0500
# 13      31.2750
# 14       7.8542
# 15      16.0000
# 16      29.1250
# 17      13.0000
# 18      18.0000
# 19       7.2250
# 20      26.0000
# 21      13.0000
# 22       8.0292
# 23      35.5000
# 24      21.0750
# 25      31.3875
# 26       7.2250
# 27     263.0000
# 28       7.8792
# 29       7.8958
#          ...
# 861     11.5000
# 862     25.9292
# 863     69.5500
# 864     13.0000
# 865     13.0000
# 866     13.8583
# 867     50.4958
# 868      9.5000
# 869     11.1333
# 870      7.8958
# 871     52.5542
# 872      5.0000
# 873      9.0000
# 874     24.0000
# 875      7.2250
# 876      9.8458
# 877      7.8958
# 878      7.8958
# 879     83.1583
# 880     26.0000
# 881      7.8958
# 882     10.5167
# 883     10.5000
# 884      7.0500
# ...

# %%
#importing numpy
import numpy as np
#mean calculation
np.mean(df['fare'])
# Out:
# 32.204207968574636

# %%
#std calculation
np.std(df['fare'])
# Out:
# 49.6655344447741

# %%
#median calculation
np.median(df['fare'])
# Out:
# 14.4542

# %%
#printing max fare
df['fare'].max()
# Out:
# 512.3292

# %%
max(df['fare'])
# Out:
# 512.3292

# %%
#sorting fare column in descending order
df['fare'].sort_values(ascending = False)
# Out:
# 679    512.3292
# 258    512.3292
# 737    512.3292
# 341    263.0000
# 438    263.0000
# 88     263.0000
# 27     263.0000
# 311    262.3750
# 742    262.3750
# 299    247.5208
# 118    247.5208
# 716    227.5250
# 557    227.5250
# 380    227.5250
# 700    227.5250
# 527    221.7792
# 377    211.5000
# 689    211.3375
# 730    211.3375
# 779    211.3375
# 318    164.8667
# 856    164.8667
# 268    153.4625
# 332    153.4625
# 609    153.4625
# 297    151.5500
# 305    151.5500
# 498    151.5500
# 708    151.5500
# 31     146.5208
#          ...
# 611      7.0500
# 477      7.0458
# 804      6.9750
# 129      6.9750
# 825      6.9500
# 411      6.8583
# 143      6.7500
# 654      6.7500
# 202      6.4958
# 371      6.4958
# 818      6.4500
# 843      6.4375
# 326      6.2375
# 872      5.0000
# 378      4.0125
# 815      0.0000
# 822      0.0000
# 481      0.0000
# 806      0.0000
# 179      0.0000
# 732      0.0000
# 466      0.0000
# 263      0.0000
# 674      0.0000
# ...

# %%
#import library to plot
import matplotlib.pyplot as plt
df['fare'].plot(kind = 'hist')
plt.xlabel('fare')
# Out:
# Text(0.5,0,'fare')

# %%
dataframe1 = pd.read_csv(r'C:\Users\Admin\Desktop\kaggle-master\kaggle-master\train.csv')
plt.hist([dataframe1[dataframe1['survived']==1]['age'], dataframe1[dataframe1['survived']==0]['age']], stacked=True, color = ['g','r'],
         bins = 30, label = ['Survived','Dead'])
plt.xlabel('Age')
plt.ylabel('Number of passengers')
plt.legend()
plt.title("Women and children first")
# Out:
# c:\users\admin\appdata\local\programs\python\python37\lib\site-packages\numpy\lib\function_base.py:780: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# c:\users\admin\appdata\local\programs\python\python37\lib\site-packages\numpy\lib\function_base.py:781: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# Text(0.5,1,'Women and children first')

# %%
sns.lmplot(x = 'age', y = 'fare',data = dataframe1, hue = 'survived', markers = ['o','x'], palette = "Set1")

# %%
sns.lmplot(x = 'age',y = 'fare',data = dataframe1, col = 'sex',palette = 'Set1')

# %%
sns.pairplot(dataframe1 , vars = ['pclass','survived'], hue = 'sex' )

# %%
plt.hist([dataframe1[dataframe1['survived']==1]['fare'], dataframe1[dataframe1['survived']==0]['fare']], stacked=True, color = ['g','r'],
         bins = 30, label = ['Survived','Dead'])
plt.xlabel('fare')
plt.ylabel('Number of passengers')
plt.legend()
plt.title("Women and children first")
# Out:
# Text(0.5,1,'Women and children first')

# %%
#probability of survival
prob_of_survival = dataframe1[dataframe1['survived']==1].count()/892
prob_of_survival['survived']
# Out:
# 0.3834080717488789

# %%
#probability of death
prob_of_dead = dataframe1[dataframe1['survived']==0].count()/892
prob_of_dead['survived']
# Out:
# 0.6154708520179372

# %%
#probability of female survival
female = dataframe1[dataframe['sex']=='female']
female_survived = female[female['survived']==1]
prob_female_survived = female_survived['survived'].count()/892
prob_female_survived
# Out:
# 0.26121076233183854

# %%
#probability of male survival
male = dataframe1[dataframe1['sex'] == 'male']
male_survived = male[male['survived'] == 1]
prob_male_survived = male_survived['survived'].count()/892
prob_male_survived
# Out:
# 0.12219730941704036

# %%
#probability of female death
female_dead = female[female['survived']==0]
prob_female_dead = female_dead['survived'].count()/892
prob_female_dead
# Out:
# 0.09080717488789238

# %%
#probability of male dead
male_dead = male[male['survived']==0]
prob_male_dead = male_dead['survived'].count()/892
prob_male_dead
# Out:
# 0.5246636771300448

# %%
# defining function to calculate ecdf
def ecdf(data):
    #no of data points
    n  = len(data)
    #x data:x
    x = np.sort(data)
    #y data:y
    y = np.arange(1,n+1)/n
    return x,y

# %%
x_fare,y_fare = ecdf(dataframe1['fare'])

# %%
plt.plot(x_fare,y_fare,marker = '.',linestyle = 'none')
plt.xlabel('fare')
plt.ylabel('CDF')
# Out:
# Text(0,0.5,'CDF')

# %%
np.percentile(dataframe['fare'],[25,50,75])
# Out:
# array([ 7.9104, 14.4542, 31.    ])

# %%
mean = np.mean(df['fare'])
std = np.std(df['fare'])
samples = np.random.normal(mean,std,size = 10000)
x_theo,y_theo = ecdf(samples)
plt.plot(x_fare,y_fare,marker = '.',linestyle = 'none')
plt.xlabel('fare')
plt.ylabel('CDF')
plt.plot(x_theo,y_theo)

# %%
x_age,y_age = ecdf(dataframe['age'])
plt.plot(x_age,y_age,marker = '.',linestyle = 'none')
plt.xlabel('Age')
plt.ylabel('CDF')
# Out:
# Text(0,0.5,'CDF')

# %%
plt.figure(figsize = (30,20))
dataframe1.boxplot(column = ['fare','age'])

# %%
#percentage of female survived
female
# Out:
#      survived  pclass                                               name  \
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 8           1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9           1       2                Nasser, Mrs. Nicholas (Adele Achem)
# 10          1       3                    Sandstrom, Miss. Marguerite Rut
# 11          1       1                           Bonnell, Miss. Elizabeth
# 14          0       3               Vestrom, Miss. Hulda Amanda Adolfina
# 15          1       2                   Hewlett, Mrs. (Mary D Kingcome)
# 18          0       3  Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 19          1       3                            Masselmani, Mrs. Fatima
# 22          1       3                        McGowan, Miss. Anna "Annie"
# ...

# %%
female_survived.count()
# Out:
# survived    233
# pclass      233
# name        233
# sex         233
# age         197
# sibsp       233
# parch       233
# ticket      233
# fare        233
# cabin        91
# embarked    231
# dtype: int64

# %%
female.count()
# Out:
# survived    314
# pclass      314
# name        314
# sex         314
# age         261
# sibsp       314
# parch       314
# ticket      314
# fare        314
# cabin        97
# embarked    312
# dtype: int64

# %%
#number to toatal people survived
survived = dataframe1[dataframe1['survived'] == 1].count()
survived['survived']
# Out:
# 342

# %%
#percentage of female survived
per_female = (female_survived['survived'].count()/survived['survived'])*100
per_female
# Out:
# 68.12865497076024

# %%
#percentage of male survived
per_male = (male_survived['survived'].count()/survived['survived'])*100
per_male
# Out:
# 31.871345029239766

# %%
#ratio of female and male survived:
ratio_survived = female_survived['survived'].count()/male_survived['survived'].count()
ratio_survived
# Out:
# 2.1376146788990824

# %%
sns.countplot(x = 'sex',hue = 'embarked',data = dataframe1)

# %%
# total number of parent children aboard
parch_total = dataframe1['parch'].sum()
parch_total
# Out:
# 340

# %%
#number of siblings/spouses aboard
sibsp_total = dataframe1['sibsp'].sum()
sibsp_total
# Out:
# 466

# %%
#removing columns which have null values
df_notnull = dataframe1.dropna(axis = 'columns')
df_notnull
# Out:
#      survived  pclass                                               name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# 6           0       1                            McCarthy, Mr. Timothy J
# 7           0       3                     Palsson, Master. Gosta Leonard
# 8           1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9           1       2                Nasser, Mrs. Nicholas (Adele Achem)
# 10          1       3                    Sandstrom, Miss. Marguerite Rut
# 11          1       1                           Bonnell, Miss. Elizabeth
# ...

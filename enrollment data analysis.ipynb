# %% [markdown]
# # Enrollment  analysis
# ### Enrollment of students to primary classes can be analyzed in various ways such as :
#    * District Wise
#    * Gendre Wise
#    * Caste Wise
#    * Year Wise

# %%
#import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#reading files which contains enrollment data
enrollment_2009 = pd.read_csv(r'H:\datasets@CivilLabs\District wise - Enrollment\Total\2009.csv')
enrollment_2010 = pd.read_csv(r'H:\datasets@CivilLabs\District wise - Enrollment\Total\2010.csv')
enrollment_2011 = pd.read_csv(r'H:\datasets@CivilLabs\District wise - Enrollment\Total\2011.csv')
enrollment_2012 = pd.read_csv(r'H:\datasets@CivilLabs\District wise - Enrollment\Total\2012.csv')
enrollment_2013 = pd.read_csv(r'H:\datasets@CivilLabs\District wise - Enrollment\Total\2013.csv')
enrollment_2014 = pd.read_csv(r'H:\datasets@CivilLabs\District wise - Enrollment\Total\2014.csv')
enrollment_2015 = pd.read_csv(r'H:\datasets@CivilLabs\District wise - Enrollment\Total\2015.csv')
enrollment_2016 = pd.read_csv(r'H:\datasets@CivilLabs\District wise - Enrollment\Total\2016.csv')
enrollment_2017 = pd.read_csv(r'H:\datasets@CivilLabs\District wise - Enrollment\Total\2017.csv')

# %% [markdown]
# ## Maximum and minimum enrollments
# ### 1. Maximum girls and boys enrollment:
#    * In year 2009 maximum boys enrollment was in **sagar** and maximum girls enrollment was in **Chattarpur**
#
#    * In year 2010 maximum boys enrollment was in **Jhabua** and maximum girls enrollment was in **Morena**
#
#    * In year 2011 maximum boys enrollment was in **Shivpuri** and maximum girls enrollment was in **Dhar**
#
#    * In year 2012 maximum boys enrollment was in **Chattarpur** and maximum girls enrollment was in **Sagar**
#
#    * In year 2013 maximum boys and Boys enrollment was in **Chattarpur**
#
#    * In year 2014 maximum boys enrollment was in **Chattarpur** and maximum girls enrollment was in **Sagar**
#
#    * In year 2015 maximum boys enrollment was in **Chattarpur** and maximum girls enrollment was in **Dhar**
#
#    * In year 2016 maximum boys enrollment was in **Chattarpur** and maximum girls enrollment was in **Dhar**
#
#    * In year 2017 maximum boys and Boys enrollment was in **Dhar**
#
#  ***Chattarpur had maximum boys enrollment for consequent four years 2012-16 and maximum girs enrollment for two years 2009 and 2013***
#
# ### 2. Minimum girls and boys enrollment:
#
#    * In year 2009 minimum boys and girls enrollment was in **agramalwa**
#
#    * In year 2010 minimum boys and girls enrollment was in **agramalwa**
#
#    * In year 2011 minimum boys and girls enrollment was in **harda**
#
#    * In year 2012 minimum boys enrollment was in **agarmalwa** and minimum girls enrollment was in **harda**
#
#    * In year 2013 minimum boys enrollment was in **agarmalwa** and minimum girls enrollment was in **harda**
#
#    * In year 2014 minimum boys enrollment was in **agarmalwa** and minimum girls enrollment was in **harda**
#
#    * In year 2015 minimum boys enrollment was in **agarmalwa** and minimum girls enrollment was in **harda**
#
#    * In year 2016 minimum boys enrollment was in **agarmalwa** and minimum girls enrollment was in **harda**
#
#    * In year 2017 minimum boys enrollment was in **agarmalwa** and minimum girls enrollment was in **harda**
#
#  ***Agarmalwa had minimum boys enrollment for all years except 2011 where harda had minimum enrollment and minimum girls was in agarmalwa for 2009,2010 and harda for 2011-17***

# %%
ax = enrollment_2009.plot('District Name',['Boys Total','Girls Total'],kind = 'bar',figsize = (20,5),color = ('purple','cyan'))
plt.title('Total boys and girls enrollment(2009)',fontsize = 30)
plt.xlabel('District',fontsize = 20)
plt.ylabel('Number of students',fontsize = 20)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.legend(fontsize = 15)

ax1 = enrollment_2010.plot('District Name',['Boys Total','Girls Total'],kind = 'bar',figsize = (20,5),color = ('purple','cyan'))
plt.title('Total boys and girls enrollment(2010)',fontsize = 30)
plt.xlabel('District',fontsize = 20)
plt.ylabel('Number of students',fontsize = 20)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.legend(fontsize = 15)

ax2 = enrollment_2011.plot('District Name',['Boys Total','Girls Total'],kind = 'bar',figsize = (20,5),color = ('purple','cyan'))
plt.title('Total boys and girls enrollment(2011)',fontsize = 30)
plt.xlabel('District',fontsize = 20)
plt.ylabel('Number of students',fontsize = 20)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.legend(fontsize = 15)

ax3 = enrollment_2012.plot('District Name',['Boys Total','Girls Total'],kind = 'bar',figsize = (20,5),color = ('purple','cyan'))
plt.title('Total boys and girls enrollment(2012)',fontsize = 30)
plt.xlabel('District',fontsize = 20)
plt.ylabel('Number of students',fontsize = 20)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.legend(fontsize = 15)

ax3 = enrollment_2013.plot('District Name',['Boys Total','Girls Total'],kind = 'bar',figsize = (20,5),color = ('purple','cyan'))
plt.title('Total boys and girls enrollment(2013)',fontsize = 30)
plt.xlabel('District',fontsize = 20)
plt.ylabel('Number of students',fontsize = 20)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.legend(fontsize = 15)

ax4 = enrollment_2014.plot('District Name',['Boys Total','Girls Total'],kind = 'bar',figsize = (20,5),color = ('purple','cyan'))
plt.title('Total boys and girls enrollment(2014)',fontsize = 30)
plt.xlabel('District',fontsize = 20)
plt.ylabel('Number of students',fontsize = 20)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.legend(fontsize = 15)

ax5 = enrollment_2015.plot('District Name',['Boys Total','Girls Total'],kind = 'bar',figsize = (20,5),color = ('purple','cyan'))
plt.title('Total boys and girls enrollment(2015)',fontsize = 30)
plt.xlabel('District',fontsize = 20)
plt.ylabel('Number of students',fontsize = 20)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.legend(fontsize = 15)

ax6 = enrollment_2016.plot('District Name',['Boys Total','Girls Total'],kind = 'bar',figsize = (20,5),color = ('purple','cyan'))
plt.title('Total boys and girls enrollment(2016)',fontsize = 30)
plt.xlabel('District',fontsize = 20)
plt.ylabel('Number of students',fontsize = 20)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.legend(fontsize = 15)

ax7 = enrollment_2017.plot('District Name',['Boys Total','Girls Total'],kind = 'bar',figsize = (20,5),color = ('purple','cyan'))
plt.title('Total boys and girls enrollment(2017)',fontsize = 30)
plt.xlabel('District',fontsize = 20)
plt.ylabel('Number of students',fontsize = 20)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.legend(fontsize = 15)

# %% [markdown]
# # District wise total students of particular caste analysis
#
# ### 1. Maximum and minimum SC enrollment:
#  * In year 2009 maximum SC enrollment was in **chattarpur** and minimum SC enrollment was in **Jhabua**
#
#  * In year 2010 maximum SC enrollment was in **Morena** and minimum SC enrollment was in **Madla and Umaria**
#
#  * In year 2011 maximum SC enrollment was in **chattarpur** and minimum SC enrollment was in **Jhabua**
#
#  * In year 2012 maximum SC enrollment was in **chattarpur** and minimum SC enrollment was in **Jhabua**
#
#  * In year 2013 maximum SC enrollment was in **chattarpur** and minimum SC enrollment was in **Jhabua**
#
#  * In year 2014 maximum SC enrollment was in **chattarpur** and minimum SC enrollment was in **Jhabua**
#
#  * In year 2015 maximum SC enrollment was in **chattarpur** and minimum SC enrollment was in **Jhabua**
#
#  * In year 2016 maximum SC enrollment was in **chattarpur** and minimum SC enrollment was in **Jhabua**
#
#  * In year 2017 maximum SC enrollment was in **chattarpur** and minimum SC enrollment was in **Jhabua**
#
# ***For all years except 2010 chattarpur had maximum SC enrollments and Jhabua had minimum SC enrollments and in year 2010 Morena had maximum SC enrollment and Mandla and Umarua had minimum SC enrollments***
#
# ### 2. Maximum and minimum ST enrollment:
#  * In year 2009 maximum ST enrollment was in **Dhar** and minimum ST enrollment was in **Bhind**
#
#  * In year 2010 maximum ST enrollment was in **Jhabua** and minimum ST enrollment was in **Shahjapur and Agarmalwa**
#
#  * In year 2011 maximum ST enrollment was in **Dhar** and minimum ST enrollment was in **Bhind**
#
#  * In year 2012 maximum ST enrollment was in **Dhar** and minimum ST enrollment was in **Bhind**
#
#  * In year 2013 maximum ST enrollment was in **Jhabua** and minimum ST enrollment was in **Bhind**
#
#  * In year 2014 maximum ST enrollment was in **Jhabua** and minimum ST enrollment was in **Bhind**
#
#  * In year 2015 maximum ST enrollment was in **Jhabua** and minimum ST enrollment was in **Bhind**
#
#  * In year 2016 maximum ST enrollment was in **Jhabua** and minimum ST enrollment was in **Bhind**
#
#  * In year 2017 maximum ST enrollment was in **Jhabua** and minimum ST enrollment was in **Bhind**
#
# ***For all years except 2010 Bhind had minimum ST enrollments and Jhabua had maximum ST enrollments for 2010 , 2013 to 2017,Dhar had maximum ST enrollments in year 2009,2011,2012***
#
# ### 3. Maximum and minimum General enrollment:
#  * In year 2009 maximum General enrollment was in **Bhind** and minimum General enrollment was in **Alirajpur**
#
#  * In year 2010 maximum General enrollment was in **Morena** and minimum General enrollment was in **Khandwa and Umaria**
#
#  * In year 2011 maximum General enrollment was in **Bhind** and minimum General enrollment was in **Alirajpur**
#
#  * In year 2012 maximum General enrollment was in **Morena** and minimum General enrollment was in **Alirajpur**
#
#  * In year 2013 maximum General enrollment was in **Morena** and minimum General enrollment was in **Alirajpur**
#
#  * In year 2014 maximum General enrollment was in **Morena** and minimum General enrollment was in **Alirajpur**
#
#  * In year 2015 maximum General enrollment was in **Morena** and minimum General enrollment was in **Alirajpur**
#
#  * In year 2016 maximum General enrollment was in **Morena** and minimum General enrollment was in **Alirajpur**
#
#  * In year 2017 maximum General enrollment was in **Morena** and minimum General enrollment was in **Alirajpur**
#
# ***For all years except 2011 aand 2009 Morena had maximum general enrollments and Alirajpur had minimum general enrollments for all years except 2010***

# %%
plt.style.use('ggplot')
ax = enrollment_2009.plot('District Name',['Total','Total ST','Total SC','Total GEN'],kind = 'bar',figsize = (30,10),cmap = 'Accent',width=.8)
plt.title('Total enrollment caste wise(2009)',fontsize = 30)
plt.xlabel('District',fontsize = 35)
plt.ylabel('Number of students',fontsize = 35)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.legend(fontsize = 20)


plt.style.use('ggplot')
ax = enrollment_2010.plot('District Name',['Total','Total ST','Total SC','Total GEN'],kind = 'bar',figsize = (30,10),cmap = 'Accent',width=.8)
plt.title('Total enrollment caste wise(2010)',fontsize = 30)
plt.xlabel('District',fontsize = 35)
plt.ylabel('Number of students',fontsize = 35)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.legend(fontsize = 20)


plt.style.use('ggplot')
ax = enrollment_2011.plot('District Name',['Total','Total ST','Total SC','Total GEN'],kind = 'bar',figsize = (30,10),cmap = 'Accent',width=.8)
plt.title('Total enrollment caste wise(2011)',fontsize = 30)
plt.xlabel('District',fontsize = 35)
plt.ylabel('Number of students',fontsize = 35)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.legend(fontsize = 20)


plt.style.use('ggplot')
ax = enrollment_2012.plot('District Name',['Total','Total ST','Total SC','Total GEN'],kind = 'bar',figsize = (30,10),cmap = 'Accent',width=.8)
plt.title('Total enrollment caste wise(2012)',fontsize = 30)
plt.xlabel('District',fontsize = 35)
plt.ylabel('Number of students',fontsize = 35)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.legend(fontsize = 20)


plt.style.use('ggplot')
ax = enrollment_2013.plot('District Name',['Total','Total ST','Total SC','Total GEN'],kind = 'bar',figsize = (30,10),cmap = 'Accent',width=.8)
plt.title('Total enrollment caste wise(2013)',fontsize = 30)
plt.xlabel('District',fontsize = 35)
plt.ylabel('Number of students',fontsize = 35)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.legend(fontsize = 20)


plt.style.use('ggplot')
ax = enrollment_2014.plot('District Name',['Total','Total ST','Total SC','Total GEN'],kind = 'bar',figsize = (30,10),cmap = 'Accent',width=.8)
plt.title('Total enrollment caste wise(2014)',fontsize = 30)
plt.xlabel('District',fontsize = 35)
plt.ylabel('Number of students',fontsize = 35)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.legend(fontsize = 20)


plt.style.use('ggplot')
ax = enrollment_2015.plot('District Name',['Total','Total ST','Total SC','Total GEN'],kind = 'bar',figsize = (30,10),cmap = 'Accent',width=.8)
plt.title('Total enrollment caste wise(2015)',fontsize = 30)
plt.xlabel('District',fontsize = 35)
plt.ylabel('Number of students',fontsize = 35)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.legend(fontsize = 20)


plt.style.use('ggplot')
ax = enrollment_2016.plot('District Name',['Total','Total ST','Total SC','Total GEN'],kind = 'bar',figsize = (30,10),cmap = 'Accent',width=.8)
plt.title('Total enrollment caste wise(2016)',fontsize = 30)
plt.xlabel('District',fontsize = 35)
plt.ylabel('Number of students',fontsize = 35)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.legend(fontsize = 20)

plt.style.use('ggplot')
ax = enrollment_2017.plot('District Name',['Total','Total ST','Total SC','Total GEN'],kind = 'bar',figsize = (30,10),cmap = 'Accent',width=.8)
plt.title('Total enrollment caste wise(2017)',fontsize = 30)
plt.xlabel('District',fontsize = 35)
plt.ylabel('Number of students',fontsize = 35)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.legend(fontsize = 20)

# %%
Total_caste_2009 = pd.read_excel(r'H:\datasets@CivilLabs\District wise - Enrollment\enrollment_2009\2009.xls')

# %% [markdown]
# ## Year wise percentage of students enrolled of particular caste analysis
#
#   In 2009 maximum percentage enrollment was of **ST girls(28.3%)** and minimum was of **general boys(5.5%)** and in rest
#   subsequent years maximum enrollment was of **ST Boys**
#
#
#   In 2010 to 2012 minimum enrollment was of **general category girls and boys**
#
#
#   In 2013 minimum enrollment was of **general category girls(4.9%)**
#
#
#   In 2014 minimum enrollment was of **general category girls and boys(4.9%)**
#
#
#   In 2015 and 2016 minimum enrollment was of **general category girls and boys(4.4%)**
#
#
#   In 2017 minimum enrollment was og **general category girls and boys(4.7%)**
#
#   ***From 2011 subsequent decrease in percentage of general enrollment boys and girls was observed with about (0.4%) decrease from 2011 to 2017***

# %%
fig = plt.figure(figsize = (5,5))
labels = ['Percentage of Boys enrolled(ST)', 'percentage of girls enrolled(ST)','Percentage of Boys enrolled(SC)', 'percentage of girls enrolled(SC)','Percentage of Boys enrolled(Genral)', 'percentage of girls enrolled(General)']
sizes = [Total_caste_2009.loc[51,'Boys ST'],Total_caste_2009.loc[51,'Girls ST'],Total_caste_2009.loc[51,'Boys SC'],Total_caste_2009.loc[51,'Girls SC'],Total_caste_2009.loc[51,'Boys GEN'],Total_caste_2009.loc[51,'Girls GEN']]
colors = ['gold', 'yellowgreen']
explode = (0.1, 0,0,0,0,0)  # explode 1st slice
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('caste wise percentage of students enrolled(2009)')
plt.axis('equal')
plt.show

fig = plt.figure(figsize = (5,5))
labels = ['Percentage of Boys enrolled(ST)', 'percentage of girls enrolled(ST)','Percentage of Boys enrolled(SC)', 'percentage of girls enrolled(SC)','Percentage of Boys enrolled(Genral)', 'percentage of girls enrolled(General)']
sizes = [enrollment_2010['Boys ST'].sum(),enrollment_2010['Girls ST'].sum(),enrollment_2010['Boys SC'].sum(),enrollment_2010['Boys SC'].sum(),enrollment_2010['Boys GEN'].sum(),enrollment_2010['Boys GEN'].sum()]
colors = ['orange', 'pink']
explode = (0.1, 0,0,0,0,0)  # explode 1st slice
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('caste wise percentage of students enrolled(2010)')
plt.axis('equal')
plt.show

fig = plt.figure(figsize = (5,5))
labels = ['Percentage of Boys enrolled(ST)', 'percentage of girls enrolled(ST)','Percentage of Boys enrolled(SC)', 'percentage of girls enrolled(SC)','Percentage of Boys enrolled(Genral)', 'percentage of girls enrolled(General)']
sizes = [enrollment_2011['Boys ST'].sum(),enrollment_2011['Girls ST'].sum(),enrollment_2011['Boys SC'].sum(),enrollment_2011['Boys SC'].sum(),enrollment_2011['Boys GEN'].sum(),enrollment_2011['Boys GEN'].sum()]
colors = ['red', 'yellow']
explode = (0.1, 0,0,0,0,0)  # explode 1st slice
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('caste wise percentage of students enrolled(2011)')
plt.axis('equal')
plt.show


fig = plt.figure(figsize = (5,5))
labels = ['Percentage of Boys enrolled(ST)', 'percentage of girls enrolled(ST)','Percentage of Boys enrolled(SC)', 'percentage of girls enrolled(SC)','Percentage of Boys enrolled(Genral)', 'percentage of girls enrolled(General)']
sizes = [enrollment_2012['Boys ST'].sum(),enrollment_2012['Girls ST'].sum(),enrollment_2012['Boys SC'].sum(),enrollment_2012['Boys SC'].sum(),enrollment_2012['Boys GEN'].sum(),enrollment_2012['Boys GEN'].sum()]
colors = ['cyan', 'purple']
explode = (0.1, 0,0,0,0,0)  # explode 1st slice
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('caste wise percentage of students enrolled(2012)')
plt.axis('equal')
plt.show


fig = plt.figure(figsize = (5,5))
labels = ['Percentage of Boys enrolled(ST)', 'percentage of girls enrolled(ST)','Percentage of Boys enrolled(SC)', 'percentage of girls enrolled(SC)','Percentage of Boys enrolled(Genral)', 'percentage of girls enrolled(General)']
sizes = [enrollment_2013['Boys ST'].sum(),enrollment_2013['Girls ST'].sum(),enrollment_2013['Boys SC'].sum(),enrollment_2013['Boys SC'].sum(),enrollment_2013['Boys GEN'].sum(),enrollment_2012['Boys GEN'].sum()]
colors = ['green', 'olive']
explode = (0.1, 0,0,0,0,0)  # explode 1st slice
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('caste wise percentage of students enrolled(2013)')
plt.axis('equal')
plt.show

fig = plt.figure(figsize = (5,5))
labels = ['Percentage of Boys enrolled(ST)', 'percentage of girls enrolled(ST)','Percentage of Boys enrolled(SC)', 'percentage of girls enrolled(SC)','Percentage of Boys enrolled(Genral)', 'percentage of girls enrolled(General)']
sizes = [enrollment_2014['Boys ST'].sum(),enrollment_2014['Girls ST'].sum(),enrollment_2014['Boys SC'].sum(),enrollment_2014['Boys SC'].sum(),enrollment_2014['Boys GEN'].sum(),enrollment_2014['Boys GEN'].sum()]
colors = ['blue', 'pink']
explode = (0.1, 0,0,0,0,0)  # explode 1st slice
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('caste wise percentage of students enrolled(2014)')
plt.axis('equal')
plt.show


fig = plt.figure(figsize = (5,5))
labels = ['Percentage of Boys enrolled(ST)', 'percentage of girls enrolled(ST)','Percentage of Boys enrolled(SC)', 'percentage of girls enrolled(SC)','Percentage of Boys enrolled(Genral)', 'percentage of girls enrolled(General)']
sizes = [enrollment_2015['Boys ST'].sum(),enrollment_2015['Girls ST'].sum(),enrollment_2015['Boys SC'].sum(),enrollment_2015['Boys SC'].sum(),enrollment_2015['Boys GEN'].sum(),enrollment_2015['Boys GEN'].sum()]
colors = ['green', 'yellow']
explode = (0.1, 0,0,0,0,0)  # explode 1st slice
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('caste wise percentage of students enrolled(2015)')
plt.axis('equal')
plt.show

fig = plt.figure(figsize = (5,5))
labels = ['Percentage of Boys enrolled(ST)', 'percentage of girls enrolled(ST)','Percentage of Boys enrolled(SC)', 'percentage of girls enrolled(SC)','Percentage of Boys enrolled(Genral)', 'percentage of girls enrolled(General)']
sizes = [enrollment_2016['Boys ST'].sum(),enrollment_2016['Girls ST'].sum(),enrollment_2016['Boys SC'].sum(),enrollment_2016['Boys SC'].sum(),enrollment_2016['Boys GEN'].sum(),enrollment_2016['Boys GEN'].sum()]
colors = ['purple', 'blue']
explode = (0.1, 0,0,0,0,0)  # explode 1st slice
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('caste wise percentage of students enrolled(2016)')
plt.axis('equal')
plt.show

fig = plt.figure(figsize = (5,5))
labels = ['Percentage of Boys enrolled(ST)', 'percentage of girls enrolled(ST)','Percentage of Boys enrolled(SC)', 'percentage of girls enrolled(SC)','Percentage of Boys enrolled(Genral)', 'percentage of girls enrolled(General)']
sizes = [enrollment_2017['Boys ST'].sum(),enrollment_2017['Girls ST'].sum(),enrollment_2017['Boys SC'].sum(),enrollment_2017['Boys SC'].sum(),enrollment_2017['Boys GEN'].sum(),enrollment_2017['Boys GEN'].sum()]
colors = ['olive', 'yellow']
explode = (0.1, 0,0,0,0,0)  # explode 1st slice
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('caste wise percentage of students enrolled(2017)')
plt.axis('equal')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
total_enrollment = pd.read_csv(r'H:\datasets@CivilLabs\District wise - Enrollment\total_enrollment.csv')

# %%
total_enrollment.plot('Year',['Total','Total Girls','Total Boys'],kind = 'bar',cmap = 'gist_rainbow')
plt.plot('Year','Total',data = total_enrollment,marker = 'o',markersize = 5,markerfacecolor = 'cyan',color ='purple',linewidth = 7)

# %% [markdown]
# # Year and gender wise analysis of total students enrolled
#    From year 2009 to 2010 sudden decrease in enrollment was observed which was 89.9% less than that of 2009
#
#    From year 2010 to 2011 increase in total enrollment was observed which was about 8%
#
#    In years 2013 to 2015 same number of enrollments were observed and then enrollment decreased by 20%
#
#    In years 2015 to 2017 same number of enrollments were observed and then enrollment decreased by 10%
#
# ## Girls enrollment percentage change
#
#   * From year 2009 to 2010 sudden decrease in enrollment of girls was observed which was 90% less than that of 2009
#
#   * From year 2010 to 2011 increase in girls enrollment was observed which was about 7.8%
#
#   * In years 2013 to 2015 same number of girls enrollments were observed and then enrollment decreased by 5.6%
#
#   * In years 2015 to 2017 same number of girls enrollments were observed and then enrollment decreased by 19.75%
#
# ## Boys enrollment percentage change
#
#   * From year 2009 to 2010 sudden decrease in enrollment of girls was observed which was 89.9% less than that of 2009
#
#   * From year 2010 to 2011 increase in girls enrollment was observed which was about 11.11%
#
#   * In years 2013 to 2015 same number of girls enrollments were observed and then enrollment decreased by 6.5%
#
#   * In years 2015 to 2017 same number of girls enrollments were observed and then enrollment decreased by 10.75%

# %%
total_class  = pd.read_csv(r'H:\datasets@CivilLabs\enrollment class wise\total class.csv')

# %% [markdown]
# # Class wise analysis of total students enrolled
#
# ## 1. Class 1 analysis:
#
#  ### Total enrollments
#
#   * With decrease in total enrollment through years, class 1 enrollments also decreased maximum enrollment to total girls and boys in class 1 was seen in 2009 and minimum in years 2016 and 2017
#
#   * Difference between total boys enrollment from year 2010 to 2011 is 23.6% and that of total girls enrollment was 26.11% and than total girls and boys enrollment remained constant from 2011 to 2012
#
#   * From year 2013 to 2014 difference of total boys enrollment was 11.8% and that of girls was 10% and than from year 2014 to 2015 total enrollments reamied constant
#
#   * From year 2015 to 2016 total boys enrollments decreased by 22% and that of girls decreased by 20% and then enrollments remained constant from 2016 to 2017
#
#  ### Caste and gender wise analysis:
#
#   * From year 2009 to 2017 total boys ST enrollments decreased by 50.9% and total girls ST enrollment by 49.7%
#
#   * From year 2009 to 2017 total boys SC enrollments decreased by 56.7% and total girls SC enrolments by 54.47%
#
#   * Frpm year 2009 to 2017 total boys general enrollments decreased by 60.65 and total girls general enrollments by 60.08%
#
#  ***Largest difference was seen in general enrollments***
#
#
# ## 1. Class 2 analysis:
#
#  ### Total enrollments
#
#   * From year 2009 to 2010 total enrollments to boys increased by 8.1% and that of girls was 18.8% in these two years total girls enrollment was higher than those of boys.
#
#   * From year 2010 to 2011 decrease in total enrollments of boys was 3.04% and that of girls was 1.8%
#
#   * From year 2011 to 2012 decrease of 19.95% in total boys enrollment and 23.3 % in total girls enrollment
#
#   * From year 2012 to 2013 increase of 2.5% in total girls enrollment and 4.5% in total girls enrollment
#   ***And than subsequent years decrease in enrollments was seen***
#
#  ### Caste and gender wise analysis:
#
#   * From year 2009 to 2017 total boys ST enrollments decreased by 16.15% and total girls ST enrollment by 19.18%
#
#   * From year 2009 to 2017 total boys SC enrollments decreased by 40.5% and total girls SC enrolments by 40.8%
#
#   * Frpm year 2009 to 2017 total boys general enrollments decreased by 46.2% and total girls general enrollments by 50.05%
#
#  ***Largest difference was seen in general enrollments and with total enrollments patterns caste wise patters also changed***
#
# ## 1. Class 3 analysis:
#
#  ### Total enrollments
#
#   * From year 2009 to 2010 total enrollments to boys increased by 24.09% and that of girls was 16.7% in these two years total girls enrollment was higher than those of boys.
#
#   * From year 2010 to 2011 decrease in total enrollments of boys was 2.7% and that of girls was 6.88%
#
#   ***And than subsequent years decrease in enrollments was seen***
#
#  ### Caste and gender wise analysis:
#
#   * From year 2009 to 2017 total boys ST enrollments decreased by 13.7% and total girls ST enrollment by 18.6%
#
#   * From year 2009 to 2017 total boys SC enrollments decreased by 39.7% and total girls SC enrolments by 40.22%
#
#   * From year 2009 to 2017 total boys general enrollments decreased by 44.2% and total girls general enrollments by 45.7%
#
#  ***Largest difference was seen in general enrollments and with total enrollments patterns caste wise patters also changed***
#
# ## 1. Class 4 analysis:
#
#  ### Total enrollments
#
#   * From year 2009 to 2010 total enrollments to boys increased by 62.04% and that of girls was 59.5% in these two years total girls enrollment was higher than those of boys.
#
#   * From year 2011 to 2014 subsequent decrease in total enrollments of girls was observed and than increase of 0.8% of from 2014 to 15
#
#   * From year 2011 to 2012 increase in total enrollments of boys was 3.5% and than subsequent decrease was observed
#
#  ### Caste and gender wise analysis:
#
#   * From year 2009 to 2017 total boys ST enrollments increased by 24.5% and total girls ST enrollment by 18.6%
#
#   * From year 2009 to 2017 total boys SC enrollments increases by 25.75% and total girls SC enrolments by 17.77%
#
#   * From year 2009 to 2017 total boys general enrollments decreased by 16.58% and total girls general enrollments by 19.8%
#
# ## 1. Class 5 analysis:
#
#  ### Total enrollments
#
#   * Boys total decrease in enrollment was in years 2012, 2014 ,2015 and 2017
#
#   * Girls decrease in enrollment was in years 2012 to 2015 and then in 2017
#
#  ### Caste and gender wise analysis:
#
#   * From year 2009 to 2017 total boys ST enrollments increased by 18.21% and total girls ST enrollment by 9.5%
#
#   * From year 2009 to 2017 total boys SC enrollments decreased by 20.75% and total girls SC enrolments decreased by 24.2%
#
#   * Frpm year 2009 to 2017 total boys general enrollments decreased by 32.02% and total girls general enrollments by 35.02%

# %%
plt.style.use('ggplot')
ax = total_class.plot('Year',['class_1_total_boys','class_1_total_girls','class_1_boys_ST','class_1_girls_ST','class_1_boys_SC','class_1_girls_SC','class_1_Boys_gen','class_1_girls_gen'],kind = 'bar',figsize = (30,10),cmap = 'gist_earth_r',width=.8)
plt.title('Total enrollment class 1',fontsize = 30)
plt.xlabel('Year',fontsize = 35)
plt.ylabel('Number of students',fontsize = 35)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.legend(ncol = 2,fontsize = 20)

plt.style.use('ggplot')
ax = total_class.plot('Year',['class_2_total_boys','class_2_total_girls','class_2_boys_ST','class_2_girls_ST','class_2_boys_SC','class_2_girls_SC','class_2_Boys_gen','class_2_girls_gen'],kind = 'bar',figsize = (30,10),cmap = 'gist_earth_r',width=.8)
plt.title('Total enrollment class 2',fontsize = 30)
plt.xlabel('Year',fontsize = 35)
plt.ylabel('Number of students',fontsize = 35)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.legend(ncol = 2,fontsize = 20)

plt.style.use('ggplot')
ax = total_class.plot('Year',['class_3_total_boys','class_3_total_girls','class_3_boys_ST','class_3_girls_ST','class_3_boys_SC','class_3_girls_SC','class_3_Boys_gen','class_3_girls_gen'],kind = 'bar',figsize = (30,10),cmap = 'gist_earth_r',width=.8)
plt.title('Total enrollment class 3',fontsize = 30)
plt.xlabel('Year',fontsize = 35)
plt.ylabel('Number of students',fontsize = 35)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.legend(ncol = 2,fontsize = 20)

plt.style.use('ggplot')
ax = total_class.plot('Year',['class_4_total_boys','class_4_total_girls','class_4_boys_ST','class_4_girls_ST','class_4_boys_SC','class_4_girls_SC','class_4_Boys_gen','class_4_girls_gen'],kind = 'bar',figsize = (30,10),cmap = 'gist_earth_r',width=.8)
plt.title('Total enrollment class 4',fontsize = 30)
plt.xlabel('Year',fontsize = 35)
plt.ylabel('Number of students',fontsize = 35)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.legend(ncol = 2,fontsize = 20)

plt.style.use('ggplot')
ax = total_class.plot('Year',['class_5_total_boys','class_5_total_girls','class_5_boys_ST','class_5_girls_ST','class_5_boys_SC','class_5_girls_SC','class_5_Boys_gen','class_5_girls_gen'],kind = 'bar',figsize = (30,10),cmap = 'gist_earth_r',width=.8)
plt.title('Total enrollment class 5',fontsize = 30)
plt.xlabel('Year',fontsize = 35)
plt.ylabel('Number of students',fontsize = 35)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.legend(ncol = 2,fontsize = 20)

# %% [markdown]
# # Year wise total enrollment in all classes

# %%
total_class.plot('Year',['class_1_total_boys','class_1_total_girls','class_2_total_boys','class_2_total_girls','class_3_total_boys','class_3_total_girls','class_4_total_boys','class_4_total_girls','class_5_total_boys','class_5_total_girls'],kind = 'bar',figsize = (20,5),color = ('red','yellow','black','pink','olive','yellowgreen','green','cyan','purple','orange'))
plt.title('Year wise total number of enrollments',fontsize = 20)
plt.xlabel('Year',fontsize = 20)
plt.ylabel('Number of students',fontsize = 20)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.legend(ncol = 5)

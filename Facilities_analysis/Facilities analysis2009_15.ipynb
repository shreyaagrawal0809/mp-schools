# %% [markdown]
# # Facilities indicators
#
# ### **Madhya Pradesh Government have been trying to provide maximum amout of facilities to both urban and rural area government  schools. In all categories of schools there have been increase in amount of facilities.**
# ### **This report gives analysis on following facilities provided by government for elementry education in both rural and urban areas between year 2009 to 2015:**
#    #### 1. Girls Toilet
#    #### 2. Electricity
#    #### 3.Computers
#    #### 4.Library
#    #### 5.Play Ground

# %%
#import libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from pylab import*
from matplotlib import gridspec

# %% [markdown]
# # Percentage of schools having electricity analysis

# %%
# reading files
electricity_rural_mp = pd.read_csv(r'H:\datasets@CivilLabs\ruralurban\Electricity\rural\electricity_rural_mp.csv')
electricity_urban_mp = pd.read_csv(r'H:\datasets@CivilLabs\ruralurban\Electricity\urban\electricity_urban_mp.csv')

# %% [markdown]
# ## Years which have highest and lowest percentage of schools with electricity
# ### 1.Rural
# ###  ***Lowest percentage of schools having electricity in rural area was in 2009-10(12.42%) and highest in 2015-16(18.01)***
# ### 2.Urban
# ### ***Lowest percentage of schools having electricity in urban area was in year 2009-10(69.95%) and highest in 2015-16(76.86)***
#
# ## Maximum change in percentage of schools having electricity
#
# ### ***Maximum change in rural area from 2013(74.89%) to 2014(76.45%) and maximum change in urban area is from 2009(69.95%) to 2010(70.57%)***

# %%
plt.style.use('ggplot')
ax=electricity_rural_mp.plot('Year',['Primary Only rural','Primary with U. Primary & Sec./Hr.Sec rural','Primary with Upper Primary rural','Upper Primary Only','Upper Primary With Sec./Hr.Sec','All Schools rural'],kind = 'bar',figsize = (15,5),cmap = 'Accent')
plt.title('Percentage of schools having electricity(rural)')
plt.ylabel('percentage of schools having electricity')
ax1=electricity_urban_mp.plot('Year',['Primary Only Urban','Primary with U. Primary & Sec./Hr.Sec Urban','Primary with Upper Primary Urban','Upper Primary Only Urban','Upper Primary With Sec./Hr.Sec Urban','All Schools Urban'],kind = 'bar',figsize = (15,5),cmap = 'Accent')
plt.title('Percentage of schools having electricity(urban)')
plt.ylabel('percentage of schools having electricity')
box = ax.get_position()
ax.legend(loc='lower center', bbox_to_anchor=(0.5, 1.05),
          ncol=3, shadow=False)
ax1.legend(loc='lower center', bbox_to_anchor=(0.5, 1.05),
          ncol=3, shadow=False)

# %% [markdown]
# ## Difference between urban and rural
#  #### **1. Primary schools only** : ***Maximum  difference between percentage of schools having electricity in urban and rural areas is in year 2011(41.26%) and minimum is in year 2015(37.05%) ***
#
#  #### **2. Primary with Upper Primary  schools only** : ***Maximum  difference between percentage of schools having electricity in urban and urban areas is in year 2010(22.13%) and minimum is in year 2015(13.91%) (A gradual decrease in difference is observed)***
#
#  #### **3. Primary with U. Primary & Sec./Hr.Sec schools only** : ***Maximum  difference between percentage of schools having electricity in urban and rural areas is in year 2010(11.35%) and minimum is in year 2009(3.18%) (A gradual decrease in difference is observed)***
#
#  #### **4. All Schools schools only**: ***Maximum  difference between percentage of schools having electricity in urban and rural areas is in year 2012(59.45%) and minimum is in year 2009(57.53%)***

# %%
electricity_rural_urban = pd.read_csv(r'H:\datasets@CivilLabs\ruralurban\electricity_rural_urban.csv')

# %%
plt.style.use('ggplot')
fig = plt.figure(figsize = (20,20))
ax = fig.add_subplot(221)
ax.bar(electricity_rural_urban['Year'],electricity_rural_urban['Primary Only Urban'],label = 'percentage of primary urban schools having electricity',color = 'r')
ax.bar(electricity_rural_urban['Year'],electricity_rural_urban['Primary Only rural'],label = 'percentage of primary rural schools having electricity',color = 'c')
plt.legend(loc = 'center')
plt.title('percentage of primary schools having electricity rural and urban')
plt.xlabel('Year',fontsize = 15)
plt.ylabel('Percentage of schools',fontsize = 15)
ax.plot(electricity_rural_urban['Year'],electricity_rural_urban['Primary Only Urban'],marker = 'o',linewidth = 5,color = 'yellow',markeredgecolor='purple',markersize = 10,markerfacecolor ='black',label = 'percentage of primary urban schools having electricity')
ax.plot(electricity_rural_urban['Year'],electricity_rural_urban['Primary Only rural'],marker = 'o',linewidth = 5,color = 'green',markeredgecolor='white',markersize = 10,markerfacecolor = 'white',label = 'percentage of primary rural schools having electricity')
plt.legend(loc = 'center')
ax.set_yticks(np.arange(0,80,10))
ax = fig.add_subplot(222)
ax.bar(electricity_rural_urban['Year'],electricity_rural_urban['Primary with Upper Primary Urban'],label = 'percentage of primary with upper primary urban schools having electricity',color = 'r')
ax.bar(electricity_rural_urban['Year'],electricity_rural_urban['Primary with Upper Primary rural'],label = 'percentage of primary with upper primary rural schools having electricity',color = 'c')
plt.legend(loc = 'lower center')
plt.title('percentage of Primary with upper primary schools having electricity rural and urban')
plt.xlabel('Year',fontsize = 15)
plt.ylabel('Percentage of schools',fontsize = 15)
ax.plot(electricity_rural_urban['Year'],electricity_rural_urban['Primary with Upper Primary rural'],label = 'percentage of primary with upper primary urban schools having electricity',marker = 'o',linewidth = 5,color = 'yellow',markeredgecolor='purple',markersize = 10,markerfacecolor ='black')
ax.plot(electricity_rural_urban['Year'],electricity_rural_urban['Primary with Upper Primary Urban'],label = 'percentage of primary with upper primary rural schools having electricity',marker = 'o',linewidth = 5,color = 'green',markeredgecolor='white',markersize = 10,markerfacecolor = 'white')
plt.legend(loc = 'lower center')
ax = fig.add_subplot(223)
ax.bar(electricity_rural_urban['Year'],electricity_rural_urban['Primary with U. Primary & Sec./Hr.Sec Urban'],label = 'percentage of Primary with U. Primary & Sec./Hr.Sec urban schools having electricity',color = 'r')
ax.bar(electricity_rural_urban['Year'],electricity_rural_urban['Primary with U. Primary & Sec./Hr.Sec rural'],label = 'percentage of Primary with U. Primary & Sec./Hr.Sec rural schools having electricity',color = 'c')
plt.legend(loc = 'lower center')
plt.title('percentage of Primary with U. Primary & Sec./Hr.Sec urban schools having electricity rural and urban')
plt.xlabel('Year',fontsize = 15)
plt.ylabel('Percentage of schools',fontsize = 15)
ax.plot(electricity_rural_urban['Year'],electricity_rural_urban['Primary with U. Primary & Sec./Hr.Sec Urban'],marker = 'o',linewidth = 5,color = 'yellow',markeredgecolor='purple',markersize = 10,markerfacecolor ='black',label = 'percentage of Primary with U. Primary & Sec./Hr.Sec  urban schools having electricity')
ax.plot(electricity_rural_urban['Year'],electricity_rural_urban['Primary with U. Primary & Sec./Hr.Sec rural'],marker = 'o',linewidth = 5,color = 'green',markeredgecolor='white',markersize = 10,markerfacecolor = 'white',label = 'percentage ofPrimary with U. Primary & Sec./Hr.Sec rural schools having electricity')
plt.legend(loc = 'lower center')
ax.set_yticks(np.arange(0,80,10))
ax = fig.add_subplot(224)
ax.bar(electricity_rural_urban['Year'],electricity_rural_urban['All Schools Urban'],label = 'percentage of All urban Schools having electricity',color = 'r')
ax.bar(electricity_rural_urban['Year'],electricity_rural_urban['All Schools rural'],label = 'percentage of All rural Schools having electricity',color = 'c')
plt.legend(loc = 'lower center')
plt.title('percentage of All Schools schools having electricity rural and urban')
plt.xlabel('Year',fontsize = 15)
plt.ylabel('Percentage of schools',fontsize = 15)
ax.plot(electricity_rural_urban['Year'],electricity_rural_urban['All Schools Urban'],label = 'percentage of All urban schools having electricity',marker = 'o',linewidth = 5,color = 'yellow',markeredgecolor='purple',markersize = 10,markerfacecolor ='black')
ax.plot(electricity_rural_urban['Year'],electricity_rural_urban['All Schools rural'],label = 'percentage of All rural schools having electricity',marker = 'o',linewidth = 5,color = 'green',markeredgecolor='white',markersize = 10,markerfacecolor = 'white')
plt.legend(loc = 'lower center')

# %% [markdown]
# # Percentage of schools having computers analysis
#
#
#  ## Difference between urban and rural
#  ### *** Difference between percentage of schools having electricity in urban and rural areas is greater than 55%   between year 2009 to 2015 ,maximum in year 2012 (59.45%) and minimum in year 2009 (57.53%)***

# %%
computers_rural_mp = pd.read_csv(r'H:\datasets@CivilLabs\ruralurban\Computers\rural\computers_rural_mp.csv')
computers_urban_mp = pd.read_csv(r'H:\datasets@CivilLabs\ruralurban\Computers\urban\computers_urban_mp.csv')
computers_urban_mp.columns = ['S.No','Year','Primary Only urban','Primary with Upper Primary urban','Primary with U. Primary & Sec./Hr.Sec urban','Upper Primary Only urban','Upper Primary With Sec./Hr.Sec urban','All Schools urban']

# %% [markdown]
# ## Years which have highest and lowest percentage of schools with computer
# ### 1.Rural
# ###  ***Lowest percentage of schools having computer in rural area was in 2009-10(6.71%) and highest in 2015-16(10.11)***
# ### 2.Urban
# ### ***Lowest percentage of schools having computer in urban area was in year 2009-10(35.05%) and highest in 2015-16(49.91)***
#
# ## Increase in percentage of schools having computers
# ### ***There is a gradual increase in percentage of schools having computers in rural and urban areas maximum change in rural area from 2014(8.52%) to 2015(10.11%) and maximum change in urban area is from 2011(35.70%) to 2012(42.68%)***

# %%
plt.style.use('ggplot')
ax=computers_rural_mp.plot('Year',['Primary Only rural','Primary with U. Primary & Sec./Hr.Sec rural','Primary with Upper Primary rural','Upper Primary Only rural','Upper Primary With Sec./Hr.Sec rural','All Schools rural'],kind = 'bar',figsize = (15,5),cmap = 'gist_rainbow')
plt.title('Percentage of schools having computer(rural)')
plt.ylabel('percentage of schools having computer')
ax1=computers_urban_mp.plot('Year',['Primary Only urban','Primary with U. Primary & Sec./Hr.Sec urban','Primary with Upper Primary urban','Upper Primary Only urban','Upper Primary With Sec./Hr.Sec urban','All Schools urban'],kind = 'bar',figsize = (15,5),cmap = 'gist_rainbow')
plt.title('Percentage of schools having computer(urban)')
plt.ylabel('percentage of schools having computer')
box = ax.get_position()
ax.legend(loc='lower center', bbox_to_anchor=(0.5, 1.05),
          ncol=3, shadow=False)
ax1.legend(loc='lower center', bbox_to_anchor=(0.5, 1.05),
          ncol=3, shadow=False)

# %% [markdown]
# ## Minimum and maximum percentage of primary schools having computers
# ###  ***Minimum percentage of schools having computer was in year 2015-16(2.14%) of category primary only and maximum percentage in year 2009-10(2.91%)***
# ###  ***Minimum percentage of schools having computer was in year 2015-16(12.89%) of category primary only and maximum percentage in year 2012-13(14.82%)***

# %% [markdown]
# ## Difference between urban and rural
#  #### **1. Primary schools only** : ***Maximum  difference between percentage of schools having computer in urban and rural areas is in year 2015(48.06%) and minimum is in year 2010(45.10%) ***(Increase in difference is observed)
#
#  #### **2. Primary with Upper Primary  schools only** : ***Maximum  difference between percentage of schools having computers in urban and rural areas is in year 2010(22.13%) and minimum is in year 2015(13.91%) (A gradual decrease in difference is observed)***
#
#  #### **3. All Schools schools only**: ***Maximum  difference between percentage of schools having computers in urban and rural areas is in year 2015(39.80%) and minimum is in year 2009(28.34%)***

# %%
computer_rural_urban = pd.read_csv(r'H:\datasets@CivilLabs\ruralurban\computer_rural_urban.csv')

# %%
plt.style.use('ggplot')
fig = plt.figure(figsize = (20,20))
ax = fig.add_subplot(221)
ax.bar(computer_rural_urban['Year'],computer_rural_urban['Primary Only urban'],label = 'percentage of primary urban schools having computer',color = 'purple')
ax.bar(computer_rural_urban['Year'],computer_rural_urban['Primary Only rural'],label = 'percentage of primary rural schools having computer',color = 'cyan')
plt.legend(loc = 'upper center')
plt.title('percentage of primary schools having computer rural and urban')
plt.xlabel('Year',fontsize = 15)
plt.ylabel('Percentage of schools',fontsize = 15)
ax.plot(computer_rural_urban['Year'],computer_rural_urban['Primary Only urban'],marker = 'o',linewidth = 5,color = 'gray',markeredgecolor='yellow',label = 'percentage of primary urban schools having computer',markerfacecolor = 'red',markersize = 10)
ax.plot(computer_rural_urban['Year'],computer_rural_urban['Primary Only rural'],marker = 'o',linewidth = 5,color = 'blue',markeredgecolor='green',label = 'percentage of primary rural schools having computer',markerfacecolor = 'yellow',markersize = 10)
plt.legend(loc = 'upper center')
ax.set_yticks(np.arange(0,80,10))
ax = fig.add_subplot(222)
ax.bar(computer_rural_urban['Year'],computer_rural_urban['Primary with Upper Primary urban'],label = 'percentage of primary with upper primary urban schools having computer',color = 'purple')
ax.bar(computer_rural_urban['Year'],computer_rural_urban['Primary with Upper Primary rural'],label = 'percentage of primary with upper primary rural schools having computer',color = 'cyan')
plt.legend(loc = 'lower center')
plt.title('percentage of Primary with upper primary schools having computer rural and urban')
plt.xlabel('Year',fontsize = 15)
plt.ylabel('Percentage of schools',fontsize = 15)
ax.plot(computer_rural_urban['Year'],computer_rural_urban['Primary with Upper Primary rural'],label = 'percentage of primary with upper primary urban schools having computer',marker = 'o',linewidth = 5,color = 'gray',markeredgecolor='yellow',markerfacecolor = 'red',markersize = 10)
ax.plot(computer_rural_urban['Year'],computer_rural_urban['Primary with Upper Primary urban'],label = 'percentage of primary with upper primary rural schools having computer',marker = 'o',linewidth = 5,color = 'blue',markeredgecolor='green',markerfacecolor = 'yellow',markersize = 10)
plt.legend(loc = 'lower center')
ax = fig.add_subplot(223)
ax.bar(computer_rural_urban['Year'],computer_rural_urban['Primary with U. Primary & Sec./Hr.Sec rural'],label = 'percentage of Primary with U. Primary & Sec./Hr.Sec urban schools having computer',color = 'purple')
ax.bar(computer_rural_urban['Year'],computer_rural_urban['Primary with U. Primary & Sec./Hr.Sec urban'],label = 'percentage of Primary with U. Primary & Sec./Hr.Sec rural schools having computer',color = 'cyan')
plt.legend(loc = 'lower center')
plt.title('percentage of Primary with U. Primary & Sec./Hr.Sec urban schools having computer rural and urban')
plt.xlabel('Year',fontsize = 15)
plt.ylabel('Percentage of schools',fontsize = 15)
ax.plot(computer_rural_urban['Year'],computer_rural_urban['Primary with U. Primary & Sec./Hr.Sec urban'],marker = 'o',linewidth = 5,color = 'gray',markeredgecolor='yellow',markerfacecolor = 'red',markersize = 10,label = 'percentage of Primary with U. Primary & Sec./Hr.Sec  urban schools having computer')
ax.plot(computer_rural_urban['Year'],computer_rural_urban['Primary with U. Primary & Sec./Hr.Sec rural'],marker = 'o',linewidth = 5,color = 'blue',markeredgecolor='green',markerfacecolor = 'yellow',markersize = 10,label = 'percentage ofPrimary with U. Primary & Sec./Hr.Sec rural schools having computer')
plt.legend(loc = 'lower center')
ax.set_yticks(np.arange(0,80,10))
ax = fig.add_subplot(224)
ax.bar(computer_rural_urban['Year'],computer_rural_urban['All Schools urban'],label = 'percentage of All Schools urban schools having computer',color = 'purple')
ax.bar(computer_rural_urban['Year'],computer_rural_urban['All Schools rural'],label = 'percentage of All Schools rural schools having computer',color = 'cyan')
plt.legend(loc = 'center')
plt.title('percentage of All Schools schools having computer rural and urban')
plt.xlabel('Year',fontsize = 15)
plt.ylabel('Percentage of schools',fontsize = 15)
ax.plot(computer_rural_urban['Year'],computer_rural_urban['All Schools urban'],label = 'percentage of All Schools urban schools having computer',marker = 'o',linewidth = 5,color = 'gray',markeredgecolor='yellow',markerfacecolor = 'red',markersize = 10)
ax.plot(computer_rural_urban['Year'],computer_rural_urban['All Schools rural'],label = 'percentage of All Schools rural schools having computer',marker = 'o',linewidth = 5,color = 'blue',markeredgecolor='green',markerfacecolor = 'yellow',markersize = 10)
plt.legend(loc = 'center')

# %%
electricity_computer_rural = pd.read_csv(r'H:\datasets@CivilLabs\ruralurban\electricity_computers_rural.csv')
electricity_computer_urban = pd.read_csv(r'H:\datasets@CivilLabs\ruralurban\electricity_computers_urban.csv')

# %% [markdown]
# ## Diffference between percentage of schools having electricity and percentage of schools having computers
#
# ### ***In rural area maximum difference is in year 2014-15(9.17%) and minimum is in year 2009(5.71%), in 2015-16 year there were still 7.90 % of schools who had electricity but no access to computer***
# ### ***In urban area difference is much greater, maximum difference was in year 2011(36.51) and minimum in year 2015(26.95%), it is observed that difference is gradually decreasing***
#
# ### ***In rural areas primary school difference  between percentage of schools having electricity and computer  is increasing i.e. from 3.71%(2009) to 6.56%(2015)***
# ### ***In urban areas primary school difference between percentage of schools having electricity and computer is increased from 2009(32.83%) to 2015(32.86%), maximum being in year 2011(34.94%)**

# %%
plt.style.use('ggplot')
fig = plt.figure(figsize = (20,20))
ax = fig.add_subplot(221)
ax.bar(electricity_computer_rural['Year'],electricity_computer_rural['All Schools rural electricity'],label = 'percentage of rural schools having electricity')
ax.bar(electricity_computer_rural['Year'],electricity_computer_rural['All Schools rural computer'],label = 'percentage of rural schools having computer')
plt.legend(loc = 'upper center')
plt.title('Difference in percentage of schools having electricity and computers(rural)')
plt.xlabel('Year',fontsize = 15)
plt.ylabel('Percentage of schools',fontsize = 15)
ax.plot(electricity_computer_rural['Year'],electricity_computer_rural['All Schools rural electricity'],marker = '>',linewidth = 5,color = 'purple',markeredgecolor='yellow',label = 'percentage of rural schools having electricity')
ax.plot(electricity_computer_rural['Year'],electricity_computer_rural['All Schools rural computer'],marker = '>',linewidth = 5,color = 'yellow',markeredgecolor='green',label = 'percentage of rural schools having computer')
plt.legend(loc = 'upper center')
ax.set_yticks(np.arange(0,80,10))
ax = fig.add_subplot(222)
ax.bar(electricity_computer_urban['Year'],electricity_computer_urban['All Schools urban electricity'],label = 'percentage of urban schools having electricity')
ax.bar(electricity_computer_urban['Year'],electricity_computer_urban['All Schools urban computer'],label = 'percentage of urban schools having computer')
plt.legend(loc = 'lower center')
plt.title('Difference in percentage of schools having electricity and computers(urban)')
plt.xlabel('Year',fontsize = 15)
plt.ylabel('Percentage of schools',fontsize = 15)
ax.plot(electricity_computer_urban['Year'],electricity_computer_urban['All Schools urban electricity'],marker = '>',linewidth = 5,color = 'purple',markeredgecolor='yellow',label ='percentage of urban schools having electricity')
ax.plot(electricity_computer_urban['Year'],electricity_computer_urban['All Schools urban computer'],marker = '>',linewidth = 5,color = 'yellow',markeredgecolor='green',label = 'percentage of urban schools having computer')
plt.legend(loc = 'lower center')

# %% [markdown]
# # Percentage of schools having girls toilet analysis

# %%
girls_toilet_rural_mp = pd.read_csv(r'H:\datasets@CivilLabs\ruralurban\Girls Toilet\rural\Girls_Toilet_rural_mp.csv')
girls_toilet_urban_mp = pd.read_csv(r'H:\datasets@CivilLabs\ruralurban\Girls Toilet\urban\Girls_Toilet_urban_mp.csv')

# %%
girls_toilet_urban_mp.columns = ['Unnamed: 0','Year','Primary Only urban','Primary with Upper Primary urban','Primary with U. Primary & Sec./Hr.Sec urban','Upper Primary Only urban','Upper Primary With Sec./Hr.Sec urban','All Schools urban']

# %% [markdown]
# ## Years which have highest and lowest percentage of schools with girls toilet
# ### 1.Rural
# ###  ***Lowest percentage of schools having girls toilet in rural area was in 2009-10(34.14%) and highest in 2015-16(96.36)***
# ### 2.Urban
# ### ***Lowest percentage of schools having girls toilet in urban area was in year 2009-10(62.0%) and highest in 2015-16(98.80)***
#
# ## Maximum change in percentage of schools having girls toilet
# ### ***There is a gradual increase in percentage of schools having girls toilet in rural and urban areas maximum change in rural area from 2014(81.77%) to 2015(193.36%) and maximum change in urban area is from 2014(96.29%) to 2015(98.80%)***

# %%
plt.style.use('ggplot')
ax=girls_toilet_rural_mp.plot('Year',['Primary Only rural','Primary with U. Primary & Sec./Hr.Sec rural','Primary with Upper Primary rural','Upper Primary Only rural','Upper Primary With Sec./Hr.Sec rural','All Schools rural'],kind = 'bar',figsize = (15,5),cmap = 'Paired_r')
plt.title('Percentage of schools having girls toilet(rural)')
plt.ylabel('percentage of schools')
ax1=girls_toilet_urban_mp.plot('Year',['Primary Only urban','Primary with U. Primary & Sec./Hr.Sec urban','Primary with Upper Primary urban','Upper Primary Only urban','Upper Primary With Sec./Hr.Sec urban','All Schools urban'],kind = 'bar',figsize = (15,5),cmap = 'Paired_r')
plt.title('Percentage of schools having girls toilet(urban)')
plt.ylabel('percentage of schools')
box = ax.get_position()
ax.legend(loc='lower center', bbox_to_anchor=(0.5, 1.05),
          ncol=3, shadow=False)
ax1.legend(loc='lower center', bbox_to_anchor=(0.5, 1.05),
          ncol=3, shadow=False)

# %%
girls_toilet_rural_urban = pd.read_csv(r'H:\datasets@CivilLabs\ruralurban\girls_toilet_rural_urban.csv')

# %% [markdown]
# ## Difference between urban and rural
#  #### **1. Primary schools only** : ***Maximum  difference between percentage of schools having girls toilet in urban and rural areas is in year 2009(21.90%) and minimum is in year 2015(0.83%) (A sudden increase in difference was in year 2014(10.65%))***
#
#  #### **2. Primary with Upper Primary  schools only** : ***Maximum  difference between percentage of schools having girls toilet in urban and rural areas is in year 2010(12.94%) and minimum is in year 2015(0.84%) (A gradual decrease in difference is observed)***
#
#  #### **3. Primary with U. Primary & Sec./Hr.Sec schools only** : ***Maximum  difference between percentage of schools having girls toilet in urban and rural areas is in year 2010(3.66%) and minimum is in year 2009(0.10%) (A gradual decrease in difference is observed)***
#
#  #### **4. All Schools schools only**: ***Maximum  difference between percentage of schools having girls toilet in urban and rural areas is in year 2010(28.73%) and minimum is in year 2015(2.44%) (A sudden increase in difference was in year 2014(14.52%))***

# %%
plt.style.use('ggplot')
fig = plt.figure(figsize = (20,20))
ax = fig.add_subplot(221)
ax.bar(girls_toilet_rural_urban['Year'],girls_toilet_rural_urban['Primary Only urban'],label = 'percentage of primary urban schools having girls toilet',color = 'black')
ax.bar(girls_toilet_rural_urban['Year'],girls_toilet_rural_urban['Primary Only rural'],label = 'percentage of primary rural schools having girls toilet',color = 'pink')
plt.legend(loc = 'lower center')
plt.title('percentage of primary schools having girls toilet rural and urban')
plt.xlabel('Year',fontsize = 15)
plt.ylabel('Percentage of schools',fontsize = 15)
ax.plot(girls_toilet_rural_urban['Year'],girls_toilet_rural_urban['Primary Only urban'],marker = 'o',linewidth = 5,color = 'gray',markeredgecolor='yellow',label = 'percentage of primary urban schools having girls toilet',markerfacecolor = 'red',markersize = 10)
ax.plot(girls_toilet_rural_urban['Year'],girls_toilet_rural_urban['Primary Only rural'],marker = 'o',linewidth = 5,color = 'blue',markeredgecolor='green',label = 'percentage of primary rural schools having girls toilet',markerfacecolor = 'yellow',markersize = 10)
plt.legend(loc = 'lower center')
ax.set_yticks(np.arange(0,80,10))
ax = fig.add_subplot(222)
ax.bar(girls_toilet_rural_urban['Year'],girls_toilet_rural_urban['Primary with Upper Primary urban'],label = 'percentage of primary with upper primary urban schools having girls toilet',color = 'black')
ax.bar(girls_toilet_rural_urban['Year'],girls_toilet_rural_urban['Primary with Upper Primary rural'],label = 'percentage of primary with upper primary rural schools having girls toilet',color = 'pink')
plt.legend(loc = 'lower center')
plt.title('percentage of Primary with upper primary schools having girls toilet rural and urban')
plt.xlabel('Year',fontsize = 15)
plt.ylabel('Percentage of schools',fontsize = 15)
ax.plot(girls_toilet_rural_urban['Year'],girls_toilet_rural_urban['Primary with Upper Primary rural'],label = 'percentage of primary with upper primary urban schools having girls toilet',marker = 'o',linewidth = 5,color = 'gray',markeredgecolor='yellow',markerfacecolor = 'red',markersize = 10)
ax.plot(girls_toilet_rural_urban['Year'],girls_toilet_rural_urban['Primary with Upper Primary urban'],label = 'percentage of primary with upper primary rural schools having girls toilet',marker = 'o',linewidth = 5,color = 'blue',markeredgecolor='green',markerfacecolor = 'yellow',markersize = 10)
plt.legend(loc = 'lower center')
ax = fig.add_subplot(223)
ax.bar(girls_toilet_rural_urban['Year'],girls_toilet_rural_urban['Primary with U. Primary & Sec./Hr.Sec urban'],label = 'percentage of Primary with U. Primary & Sec./Hr.Sec urban schools having girls toilet',color = 'black')
ax.bar(girls_toilet_rural_urban['Year'],girls_toilet_rural_urban['Primary with U. Primary & Sec./Hr.Sec rural'],label = 'percentage of Primary with U. Primary & Sec./Hr.Sec rural schools having girls toilet',color = 'pink')
plt.legend(loc = 'lower center')
plt.title('percentage of Primary with U. Primary & Sec./Hr.Sec urban schools having girls toilet rural and urban')
plt.xlabel('Year',fontsize = 15)
plt.ylabel('Percentage of schools',fontsize = 15)
ax.plot(girls_toilet_rural_urban['Year'],girls_toilet_rural_urban['Primary with U. Primary & Sec./Hr.Sec urban'],marker = 'o',linewidth = 5,color = 'gray',markeredgecolor='yellow',markerfacecolor = 'red',markersize = 10,label = 'percentage of Primary with U. Primary & Sec./Hr.Sec  urban schools having girls toilet')
ax.plot(girls_toilet_rural_urban['Year'],girls_toilet_rural_urban['Primary with U. Primary & Sec./Hr.Sec rural'],marker = 'o',linewidth = 5,color = 'blue',markeredgecolor='green',markerfacecolor = 'yellow',markersize = 10,label = 'percentage ofPrimary with U. Primary & Sec./Hr.Sec rural schools having girls toilet')
plt.legend(loc = 'lower center')
ax.set_yticks(np.arange(0,80,10))
ax = fig.add_subplot(224)
ax.bar(girls_toilet_rural_urban['Year'],girls_toilet_rural_urban['All Schools urban'],label = 'percentage of All Schools with upper primary urban schools having girls toilet',color = 'black')
ax.bar(girls_toilet_rural_urban['Year'],girls_toilet_rural_urban['All Schools rural'],label = 'percentage of All Schools with upper primary rural schools having girls toilet',color = 'pink')
plt.legend(loc = 'lower center')
plt.title('percentage of All Schools schools having girls toilet rural and urban')
plt.xlabel('Year',fontsize = 15)
plt.ylabel('Percentage of schools',fontsize = 15)
ax.plot(girls_toilet_rural_urban['Year'],girls_toilet_rural_urban['All Schools urban'],label = 'percentage of All Schools urban schools having girls toilet',marker = 'o',linewidth = 5,color = 'gray',markeredgecolor='yellow',markerfacecolor = 'red',markersize = 10)
ax.plot(girls_toilet_rural_urban['Year'],girls_toilet_rural_urban['All Schools rural'],label = 'percentage of All Schools rural schools having girls toilet',marker = 'o',linewidth = 5,color = 'blue',markeredgecolor='green',markerfacecolor = 'yellow',markersize = 10)
plt.legend(loc = 'lower center')

# %% [markdown]
# ## Difference between percentge of schools having girls toilet and percentage to schools having boys toilet

# %%
boys_toilet_rural_mp = pd.read_csv(r'H:\datasets@CivilLabs\ruralurban\Boys Toilet\rural\Boys_Toilet_rural_mp.csv')
boys_toilet_urban_mp = pd.read_csv(r'H:\datasets@CivilLabs\ruralurban\Boys Toilet\urban\Boys_Toilet_urban_mp.csv')

# %%
boys_toilet_urban_mp.columns = ['Unnamed: 0','Year','Primary Only urban','Primary with Upper Primary urban','Primary with U. Primary & Sec./Hr.Sec urban','Upper Primary Only urban','Upper Primary With Sec./Hr.Sec urban','All Schools urban']

# %%
plt.figure(figsize = (10,10))
ax = plt.subplot(1,1,1)
plt.plot( 'Year', 'All Schools rural', data=girls_toilet_rural_mp, marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=7,label = 'percentage of all schools having girls toilet')
plt.plot( 'Year', 'All Schools rural', data=boys_toilet_rural_mp, marker='o', markerfacecolor='blue', markersize=12, color='Red', linewidth=7,label = "percentage of all schools having boys toilet")
plt.legend(('percentage of all schools having girls toilet','percentage of all schools having boys toilet'),loc = 'lower right',fontsize = 10)
plt.title('Percentage of schools having girls toilet and percentage of schools having boys toilet(rural)')
plt.xlabel('Year',fontsize = 25)
plt.ylabel('percentage of schools',fontsize = 25)
# Out:
# Text(0,0.5,'percentage of schools')

# %%
plt.figure(figsize = (10,10))
ax = plt.subplot(1,1,1)
plt.plot( 'Year', 'All Schools urban', data=girls_toilet_urban_mp, marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=7,label = 'percentage of all schools having girls toilet')
plt.plot( 'Year', 'All Schools urban', data=boys_toilet_urban_mp, marker='o', markerfacecolor='blue', markersize=12, color='Red', linewidth=7,label = "percentage of all schools having boys toilet")
plt.legend(('percentage of all schools having girls toilet','percentage of all schools having boys toilet'),loc = 'lower right',fontsize = 10)
plt.title('Percentage of schools having girls toilet and percentage of schools having boys toilet(urban)')
plt.xlabel('Year',fontsize = 25)
plt.ylabel('percentage of schools',fontsize = 25)
# Out:
# Text(0,0.5,'percentage of schools')

# %% [markdown]
# # Percentage of schools having library analysis

# %%
library_rural_mp = pd.read_csv(r'H:\datasets@CivilLabs\ruralurban\Library\rural\library_rural_mp.csv')
library_urban_mp = pd.read_csv(r'H:\datasets@CivilLabs\ruralurban\Library\urban\library_urban_mp.csv')
library_urban_mp.columns = ['Unnamed: 0','Year','Primary Only urban','Primary with Upper Primary urban','Primary with U. Primary & Sec./Hr.Sec urban','Upper Primary Only urban','Upper Primary With Sec./Hr.Sec urban','All Schools urban']

# %% [markdown]
# ## Years which have highest and lowest percentage of schools with library
# ### 1.Rural
# ###  ***Lowest percentage of schools having library in rural area was in 2009-10(47.87%) and highest in 2015-16(90.09%)***
# ### 2.Urban
# ### ***Lowest percentage of schools having library in urban area was in year 2009-10(55.36%) and highest in 2015-16(90.12%)***

# %%
plt.style.use('ggplot')
ax=library_rural_mp.plot('Year',['Primary Only rural','Primary with U. Primary & Sec./Hr.Sec rural','Primary with Upper Primary rural','Upper Primary Only rural','Upper Primary With Sec./Hr.Sec rural','All Schools rural'],kind = 'bar',figsize = (15,5),cmap = 'plasma')
plt.title('Percentage of schools having library(rural)')
plt.ylabel('percentage of school')
ax1=library_urban_mp.plot('Year',['Primary Only urban','Primary with U. Primary & Sec./Hr.Sec urban','Primary with Upper Primary urban','Upper Primary Only urban','Upper Primary With Sec./Hr.Sec urban','All Schools urban'],kind = 'bar',figsize = (15,5),cmap = 'plasma')
plt.title('Percentage of schools having library(urban)')
plt.ylabel('percentage of schools')
box = ax.get_position()
ax.legend(loc='lower center', bbox_to_anchor=(0.5, 1.05),
          ncol=3, shadow=False)
ax1.legend(loc='lower center', bbox_to_anchor=(0.5, 1.05),
          ncol=3, shadow=False)

# %%
library_rural_urban = pd.read_csv(r'H:\datasets@CivilLabs\ruralurban\library_rural_urban.csv')

# %% [markdown]
# ## Difference between urban and rural
#  #### **1. Primary schools only** : From year 2009 to 2012 percentage of schools having libraries in rural was smaller than that of urban and then in year 2013 sudden increase in percentage of rural and urban schools was observed in rural schools it was 21.16% and in urban it was 18.32%. From year 2014 to 2015 percentage of rural schools having library becomes higher than urban***
#
#  #### **2. Primary with Upper Primary  schools only** : ***Maximum  difference between percentage of schools having library in urban and rural areas is in year 2010(11.46%) and minimum is in year 2015(0.0%) (percentage of rural schools having library was greater than percentage of urban schools having library in year 2013 and it was greater by 0.15%)***
#
#  #### **3. Primary with U. Primary & Sec./Hr.Sec schools only** : ***In years 2010,2011,2013 to 2014 percentage of schools having library in rural areas was greater than those of schools having library in urban areas***
#  #### **4. All Schools schools only**: ***From years 2011 to 2015 percentage of rural schools having library was greater than that of urban schools having library***

# %%
plt.style.use('ggplot')
fig = plt.figure(figsize = (20,20))
ax = fig.add_subplot(221)
ax.bar(library_rural_urban['Year'],library_rural_urban['Primary Only rural'],color = 'brown')
ax.bar(library_rural_urban['Year'],library_rural_urban['Primary Only urban'],color = 'green')
plt.legend(('rural','urban'),loc = 'lower center')
plt.title('percentage of primary schools having library rural and urban')
plt.xlabel('Year',fontsize = 15)
plt.ylabel('Percentage of schools',fontsize = 15)
ax.plot(library_rural_urban['Year'],library_rural_urban['Primary Only rural'],marker = 'o',linewidth = 5,color = 'red',markeredgecolor='yellow',label = 'percentage of primary urban schools having library',markerfacecolor = 'green',markersize = 10)
ax.plot(library_rural_urban['Year'],library_rural_urban['Primary Only urban'],marker = 'o',linewidth = 5,color = 'yellow',markeredgecolor='green',label = 'percentage of primary rural schools having library',markerfacecolor = 'pink',markersize = 10)
plt.legend(loc = 'lower center')
ax.set_yticks(np.arange(0,80,10))

ax = fig.add_subplot(222)
ax.bar(library_rural_urban['Year'],library_rural_urban['Primary with Upper Primary urban'],color = 'brown')
ax.bar(library_rural_urban['Year'],library_rural_urban['Primary with Upper Primary rural'],color = 'green')
plt.legend(loc = 'lower center')
plt.title('percentage of Primary with upper primary schools having library rural and urban')
plt.xlabel('Year',fontsize = 15)
plt.ylabel('Percentage of schools',fontsize = 15)
ax.plot(library_rural_urban['Year'],library_rural_urban['Primary with Upper Primary urban'],label = 'percentage of primary urban schools having library',marker = 'o',linewidth = 5,color = 'red',markeredgecolor='yellow',markerfacecolor = 'green',markersize = 10)
ax.plot(library_rural_urban['Year'],library_rural_urban['Primary with Upper Primary rural'],label = 'percentage of primary urban schools having library',marker = 'o',linewidth = 5,color = 'yellow',markeredgecolor='green',markerfacecolor = 'pink',markersize = 10)
plt.legend(loc = 'lower center')

ax = fig.add_subplot(223)
ax.bar(library_rural_urban['Year'],library_rural_urban['Primary with U. Primary & Sec./Hr.Sec urban'],color = 'brown')
ax.bar(library_rural_urban['Year'],library_rural_urban['Primary with U. Primary & Sec./Hr.Sec rural'],color = 'green')
plt.legend(loc = 'lower center')
plt.title('percentage of Primary with U. Primary & Sec./Hr.Sec urban schools having library rural and urban')
plt.xlabel('Year',fontsize = 15)
plt.ylabel('Percentage of schools',fontsize = 15)
ax.plot(library_rural_urban['Year'],library_rural_urban['Primary with U. Primary & Sec./Hr.Sec urban'],marker = 'o',linewidth = 5,color = 'red',markeredgecolor='yellow',markerfacecolor = 'green',markersize = 10,label = 'percentage of Primary with U. Primary & Sec./Hr.Sec  urban schools having library')
ax.plot(library_rural_urban['Year'],library_rural_urban['Primary with U. Primary & Sec./Hr.Sec rural'],marker = 'o',linewidth = 5,color = 'yellow',markeredgecolor='green',markerfacecolor = 'pink',markersize = 10,label = 'percentage of Primary with U. Primary & Sec./Hr.Sec rural schools having library')
plt.legend(loc = 'lower center')
ax.set_yticks(np.arange(0,80,10))
ax = fig.add_subplot(224)
ax.bar(library_rural_urban['Year'],library_rural_urban['All Schools urban'],color = 'brown')
ax.bar(library_rural_urban['Year'],library_rural_urban['All Schools rural'],color = 'green')
plt.legend(loc = 'lower center')
plt.title('percentage of All Schools schools having library rural and urban')
plt.xlabel('Year',fontsize = 15)
plt.ylabel('Percentage of schools',fontsize = 15)
ax.plot(library_rural_urban['Year'],library_rural_urban['All Schools urban'],label = 'percentage of All Schools urban schools having library',marker = 'o',linewidth = 5,color = 'red',markeredgecolor='yellow',markerfacecolor = 'green',markersize = 10)
ax.plot(library_rural_urban['Year'],library_rural_urban['All Schools rural'],label = 'percentage of All Schools rural schools having library',marker = 'o',linewidth = 5,color = 'yellow',markeredgecolor='green',markerfacecolor = 'pink',markersize = 10)
plt.legend(loc = 'lower center')
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# # Percentage of schools having playground analysis

# %%
Play_Ground_rural_mp = pd.read_csv(r'H:\datasets@CivilLabs\ruralurban\Play_Ground\rural\Play_Ground_rural_mp.csv')
Play_Ground_urban_mp = pd.read_csv(r'H:\datasets@CivilLabs\ruralurban\Play_Ground\urban\Play_Ground_urban_mp.csv')
Play_Ground_urban_mp.columns = ['Unnamed: 0','Year','Primary Only urban','Primary with Upper Primary urban','Primary with U. Primary & Sec./Hr.Sec urban','Upper Primary Only urban','Upper Primary With Sec./Hr.Sec urban','All Schools urban']

# %% [markdown]
# ## Years which have highest and lowest percentage of schools with playground
# ### 1.Rural
# ###  ***Lowest percentage of schools having playground in rural area was in 2010-11(51.25%) and highest in 2015-16(62.96%)***
# ### 2.Urban
# ### ***Lowest percentage of schools having library in playground area was in year 2010-11(74.07%) and highest in 2015-16(84.47%)***

# %%
plt.style.use('ggplot')
ax=Play_Ground_rural_mp.plot('Year',['Primary Only rural','Primary with U. Primary & Sec./Hr.Sec rural','Primary with Upper Primary rural','Upper Primary Only rural','Upper Primary With Sec./Hr.Sec rural','All Schools rural'],kind = 'bar',figsize = (15,5),cmap = 'RdYlBu')
plt.title('Percentage of schools having play ground(rural)')
plt.ylabel('percentage of schools')
ax1=Play_Ground_urban_mp.plot('Year',['Primary Only urban','Primary with U. Primary & Sec./Hr.Sec urban','Primary with Upper Primary urban','Upper Primary Only urban','Upper Primary With Sec./Hr.Sec urban','All Schools urban'],kind = 'bar',figsize = (15,5),cmap = 'RdYlBu')
plt.title('Percentage of schools having play ground(urban)')
plt.ylabel('percentage of schools')
box = ax.get_position()
ax.legend(loc='lower center', bbox_to_anchor=(0.5, 1.05),
          ncol=3, shadow=False)
ax1.legend(loc='lower center', bbox_to_anchor=(0.5, 1.05),
          ncol=3, shadow=False)

# %%
playground_rural_urban = pd.read_csv(r'H:\datasets@CivilLabs\ruralurban\Play_Ground_rural_urban.csv')

# %%
playground_rural_urban.columns= ['Unnamed: 0','Year','Primary Only rural','Primary with Upper Primary rural','Primary with U. Primary & Sec./Hr.Sec rural','Upper Primary Only rural','Upper Primary With Sec./Hr.Sec rural','All Schools rural','Year.1','Primary Only urban','Primary with Upper Primary urban','Primary with U. Primary & Sec./Hr.Sec urban','Upper Primary Only urban','Upper Primary With Sec./Hr.Sec urban','All Schools urban']

# %% [markdown]
# ## Difference between urban and rural
#  #### **1. Primary schools only** : ***Maximum difference between percentage of urban and rural schools having playground was in year 2010(14.57%)***
#
#  #### **2. Primary with Upper Primary  schools only** : ***From year 2009 to 2013 percentage of rural schools having playground was greaster than percentage of urban schools having playground and than from 2013 to 2015 percentgae of urban schools having play ground necomes higher than rural schools
#
#  #### **3. Primary with U. Primary & Sec./Hr.Sec schools only** : ***In years 2010 to 2011,2014 to 2015 percentage of schools having play ground in rural areas was greater than those of schools having play ground in urban areas***
#
#  #### **4. All Schools schools only**: ***From years 2009 to 2015 percentage of urban schools having playground was greater than that of rural schools having playground***

# %%
plt.style.use('ggplot')
fig = plt.figure(figsize = (20,20))
ax = fig.add_subplot(221)
ax.bar(playground_rural_urban['Year'],playground_rural_urban['Primary Only urban'],label = 'percentage of primary urban schools having play ground',color = 'black')
ax.bar(playground_rural_urban['Year'],playground_rural_urban['Primary Only rural'],label = 'percentage of primary rural schools having play ground',color = 'red')
plt.legend(loc = 'lower center')
plt.title('percentage of primary schools having play ground rural and urban')
plt.xlabel('Year',fontsize = 15)
plt.ylabel('Percentage of schools',fontsize = 15)
ax.plot(playground_rural_urban['Year'],playground_rural_urban['Primary Only urban'],marker = 'o',linewidth = 5,color = 'gray',markeredgecolor='yellow',label = 'percentage of primary urban schools having play ground',markerfacecolor = 'red',markersize = 10)
ax.plot(playground_rural_urban['Year'],playground_rural_urban['Primary Only rural'],marker = 'o',linewidth = 5,color = 'blue',markeredgecolor='green',label = 'percentage of primary rural schools having play ground',markerfacecolor = 'yellow',markersize = 10)
plt.legend(loc = 'lower center')
ax.set_yticks(np.arange(0,80,10))
ax = fig.add_subplot(222)
ax.bar(playground_rural_urban['Year'],playground_rural_urban['Primary with Upper Primary urban'],label = 'percentage of primary with upper primary urban schools having play ground',color = 'black')
ax.bar(playground_rural_urban['Year'],playground_rural_urban['Primary with Upper Primary rural'],label = 'percentage of primary with upper primary rural schools having play ground',color = 'red')
plt.legend(loc = 'lower center')
plt.title('percentage of Primary with upper primary schools having play ground rural and urban')
plt.xlabel('Year',fontsize = 15)
plt.ylabel('Percentage of schools',fontsize = 15)
ax.plot(playground_rural_urban['Year'],playground_rural_urban['Primary with Upper Primary urban'],label = 'percentage of primary with upper primary urban schools having play ground',marker = 'o',linewidth = 5,color = 'gray',markeredgecolor='yellow',markerfacecolor = 'red',markersize = 10)
ax.plot(playground_rural_urban['Year'],girls_toilet_rural_urban['Primary with Upper Primary rural'],label = 'percentage of primary with upper primary rural schools having play ground',marker = 'o',linewidth = 5,color = 'blue',markeredgecolor='green',markerfacecolor = 'yellow',markersize = 10)
plt.legend(loc = 'lower center')
ax = fig.add_subplot(223)
ax.bar(playground_rural_urban['Year'],playground_rural_urban['Primary with U. Primary & Sec./Hr.Sec urban'],label = 'percentage of Primary with U. Primary & Sec./Hr.Sec urban schools having play ground',color = 'black')
ax.bar(playground_rural_urban['Year'],playground_rural_urban['Primary with U. Primary & Sec./Hr.Sec rural'],label = 'percentage of Primary with U. Primary & Sec./Hr.Sec rural schools having play ground',color = 'red')
plt.legend(loc = 'lower center')
plt.title('percentage of Primary with U. Primary & Sec./Hr.Sec urban schools having play ground rural and urban')
plt.xlabel('Year',fontsize = 15)
plt.ylabel('Percentage of schools',fontsize = 15)
ax.plot(playground_rural_urban['Year'],playground_rural_urban['Primary with U. Primary & Sec./Hr.Sec urban'],marker = 'o',linewidth = 5,color = 'gray',markeredgecolor='yellow',markerfacecolor = 'red',markersize = 10,label = 'percentage of Primary with U. Primary & Sec./Hr.Sec  urban schools having play ground')
ax.plot(playground_rural_urban['Year'],playground_rural_urban['Primary with U. Primary & Sec./Hr.Sec rural'],marker = 'o',linewidth = 5,color = 'blue',markeredgecolor='green',markerfacecolor = 'yellow',markersize = 10,label = 'percentage ofPrimary with U. Primary & Sec./Hr.Sec rural schools having play ground')
plt.legend(loc = 'lower center')
ax.set_yticks(np.arange(0,80,10))
ax = fig.add_subplot(224)
ax.bar(playground_rural_urban['Year'],playground_rural_urban['All Schools urban'],label = 'percentage of All Schools with upper primary urban schools having play ground',color = 'black')
ax.bar(playground_rural_urban['Year'],playground_rural_urban['All Schools rural'],label = 'percentage of All Schools with upper primary rural schools having play ground',color = 'red')
plt.legend(loc = 'lower center')
plt.title('percentage of All Schools schools having play ground rural and urban')
plt.xlabel('Year',fontsize = 15)
plt.ylabel('Percentage of schools',fontsize = 15)
ax.plot(playground_rural_urban['Year'],playground_rural_urban['All Schools urban'],label = 'percentage of All Schools urban schools having play ground',marker = 'o',linewidth = 5,color = 'gray',markeredgecolor='yellow',markerfacecolor = 'red',markersize = 10)
ax.plot(playground_rural_urban['Year'],playground_rural_urban['All Schools rural'],label = 'percentage of All Schools rural schools having play ground',marker = 'o',linewidth = 5,color = 'blue',markeredgecolor='green',markerfacecolor = 'yellow',markersize = 10)
plt.legend(loc = 'lower center')
